# %%
import pandas as pd

ALC_df = pd.read_excel("/Users/shubhamarundekatey/Downloads/OFLC_Wages_2025-26_Updated/ALC_24_25_Next.xlsx")

# %%
df = ALC_df
df

# %%
df = df[~((df["File"] == "ALC_24") & (df["Occurances"] == 2))]

# %%
df=df.reset_index(drop=True)

# %%
df
# Out:
#           File    Area  SocCode  ...        Label             Concat  Occurances
# 0       ALC_24  100001  45-3031  ...          NaN  100001 -45-3031-1           1
# 1       ALC_25  100001  11-1011  ...          NaN   100001-11-1011-2           2
# 2       ALC_25  100001  11-1021  ...          NaN   100001-11-1021-1           2
# 3       ALC_25  100001  11-1031  ...  Annual Wage   100001-11-1031-1           2
# 4       ALC_25  100001  11-2011  ...          NaN   100001-11-2011-2           2
# ...        ...     ...      ...  ...          ...                ...         ...
# 513862  ALC_25  900001  53-7072  ...          NaN   900001-53-7072-4           2
# 513863  ALC_25  900001  53-7073  ...          NaN   900001-53-7073-4           2
# 513864  ALC_25  900001  53-7081  ...          NaN   900001-53-7081-2           2
# 513865  ALC_25  900001  53-7121  ...          NaN   900001-53-7121-2           2
# 513866  ALC_25  900001  53-7199  ...          NaN   900001-53-7199-2           2
#
# ...

# %%
df.to_excel("/Users/shubhamarundekatey/Downloads/OFLC_Wages_2025-26_Updated/ALC24_25_Py.xlsx", index=False)
