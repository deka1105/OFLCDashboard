# %%
import pandas as pd

ALC_df = pd.read_excel("/Users/shubhamarundekatey/Downloads/OFLC_Wages_2025-26_Updated/ALC24_25_Py.xlsx")

# %%
df = ALC_df
df
# Out:
#           File     Area  SocCode  GeoLvl    Level1    Level2    Level3  \
# 0       ALC_24   100001  45-3031       1     18.88     18.88     18.88
# 1       ALC_25   100001  11-1011       2     46.05     74.94    103.82
# 2       ALC_25   100001  11-1021       1     24.19     39.31     54.43
# 3       ALC_25   100001  11-1031       1  19560.00  27760.00  35960.00
# 4       ALC_25   100001  11-2011       2     37.63     47.96     58.30
# ...        ...      ...      ...     ...       ...       ...       ...
# 963302   ALC26    43100  45-3031       3     20.84     20.84     20.84
# 963303   ALC26    48260  45-3031       3     20.36     20.36     20.36
# 963304   ALC26  3900002  45-3031       1     21.43     21.43     21.43
# 963305   ALC26  6600001  45-3031       1     20.39     20.39     20.39
# 963306   ALC26  7800001  45-3031       1     19.27     19.27     19.27
#
#           Level4   Average        Label             Concat  Occurances
# ...

# %%
len(df)-len(df[((df["File"] == "ALC_24") & (df["Occurances"] == 2))])
# Out:
# 946302

# %%
len(df[((df["File"] == "ALC_25") & (df["Occurances"] == 2))])
# Out:
# 352115

# %%
len(df[((df["File"] == "ALC26") & (df["Occurances"] == 2))])
# Out:
# 369120

# %%
df = df[~((df["File"] == "ALC_24") & (df["Occurances"] == 2))]
len(df)
# Out:
# 946302

# %%
len(df)-len(df[((df["File"] == "ALC_25") & (df["Occurances"] == 2))])
# Out:
# 594187

# %%
df = df[~((df["File"] == "ALC_25") & (df["Occurances"] == 2))]
len(df)
# Out:
# 594187

# %%
df=df.reset_index(drop=True)

# %%
df
# Out:
#           File     Area  SocCode  GeoLvl  Level1  Level2  Level3  Level4  \
# 0       ALC_24   100001  45-3031       1   18.88   18.88   18.88   18.88
# 1       ALC_25   100001  11-1011       2   46.05   74.94  103.82  132.71
# 2       ALC_25   100001  11-2011       2   37.63   47.96   58.30   68.63
# 3       ALC_24   100001  11-9041       2   44.25   56.69   69.14   81.58
# 4       ALC_25   100001  11-9072       2   14.58   22.79   31.01   39.22
# ...        ...      ...      ...     ...     ...     ...     ...     ...
# 594182   ALC26    43100  45-3031       3   20.84   20.84   20.84   20.84
# 594183   ALC26    48260  45-3031       3   20.36   20.36   20.36   20.36
# 594184   ALC26  3900002  45-3031       1   21.43   21.43   21.43   21.43
# 594185   ALC26  6600001  45-3031       1   20.39   20.39   20.39   20.39
# 594186   ALC26  7800001  45-3031       1   19.27   19.27   19.27   19.27
#
#         Average Label             Concat  Occurances
# ...

# %%
df.to_csv("/Users/shubhamarundekatey/Downloads/OFLC_Wages_2025-26_Updated/ALC_All.csv", index=False)

# %%
xls = pd.ExcelFile("/Users/shubhamarundekatey/Downloads/OFLC_Wages_2025-26_Updated/Geography23-24-25-26.xlsx")
df1 = pd.read_excel(xls, 'Final_Filter')
df1
# Out:
#          Area                                AreaName StateAb        State  \
# 0     1000005    Sussex Delaware nonmetropolitan area      DE     Delaware
# 1      100001  Northwest Alabama nonmetropolitan area      AL      Alabama
# 2      100001  Northwest Alabama nonmetropolitan area      AL      Alabama
# 3      100001  Northwest Alabama nonmetropolitan area      AL      Alabama
# 4      100001  Northwest Alabama nonmetropolitan area      AL      Alabama
# ...       ...                                     ...     ...          ...
# 5854   900001        Connecticut nonmetropolitan area      CT  Connecticut
# 5855   900001        Connecticut nonmetropolitan area      CT  Connecticut
# 5856   900001        Connecticut nonmetropolitan area      CT  Connecticut
# 5857   900001        Connecticut nonmetropolitan area      CT  Connecticut
# 5858   900001        Connecticut nonmetropolitan area      CT  Connecticut
#
#        CountyTownName
# 0       Sussex County
# ...

# %%
df1.to_csv("/Users/shubhamarundekatey/Downloads/OFLC_Wages_2025-26_Updated/Geo_All.csv", index=False)

# %%
xls = pd.ExcelFile("/Users/shubhamarundekatey/Downloads/OFLC_Wages_2025-26_Updated/Profession23-24-25-26.xlsx")
df2 = pd.read_excel(xls, 'Uniques')
df2
# Out:
#               OES_SOCCODE OES_SOCCODE_True  \
# 0                 11-1011          11-1011
# 1                 11-1011          11-1011
# 2                 11-1021          11-1021
# 3                 11-1031          11-1031
# 4     2011-11-01 00:00:00          11-2011
# ...                   ...              ...
# 1368              53-7073          53-7073
# 1369              53-7081          53-7081
# 1370              53-7111          53-7111
# 1371              53-7121          53-7121
# 1372              53-7199          53-7199
#
#                                    OES_SOCTITLE        TruncOnetCode  \
# 0                              Chief Executives              11-1011
# 1                              Chief Executives              11-1011
# 2               General and Operations Managers              11-1021
# 3                                   Legislators              11-1031
# 4           Advertising and Promotions Managers  2011-11-01 00:00:00
# ...

# %%
df2.to_csv("/Users/shubhamarundekatey/Downloads/OFLC_Wages_2025-26_Updated/Prof_All.csv", index=False)
